# %%
import string
import random
import datetime
import json

def id_generator(size=6, chars=string.ascii_lowercase + string.digits):
    return ''.join(random.choice(chars) for _ in range(size))

class Object:
    def toJSON(self):
        return json.dumps(self, default=lambda o: o.__dict__, 
            sort_keys=False, indent=4)

for i in range(0,5):
    
    typeOrder=['OrderPlaced','OrderAccepted','OrderCancelled']
    if i<3:
        hour=datetime.datetime.now().strftime('%Y'+'-'+'%m'+'-'+'%d'+'T'+'%H'+':'+'%M'+':'+'%S'+'Z')


        
        me = Object()
        me.Type = typeOrder[0]
        me.Data = Object()
        me.Data.OrderId = (id_generator(8)+'-'+id_generator(4)+'-'+id_generator(4)+'-'+id_generator(4)+'-'+id_generator(12))
        me.Data.TimestampUtc=hour


        #typeOrder=['OrderPlaced','OrderAccepted','OrderCancelled']
        me_1 = Object()
        me_1.Type = typeOrder[1]
        me_1.Data = Object()
        me_1.Data.OrderId = (id_generator(8)+'-'+id_generator(4)+'-'+id_generator(4)+'-'+id_generator(4)+'-'+id_generator(12))
        me_1.Data.TimestampUtc=hour
    else:
        
        hour=datetime.datetime.now().strftime('%Y'+'-'+'%m'+'-'+'%d'+'T'+'%H'+':'+'%M'+':'+'%S'+'Z')
        #typeOrder=['OrderPlaced','OrderAccepted','OrderCancelled']
        me = Object()
        me.Type = typeOrder[0]
        me.Data = Object()
        me.Data.OrderId = (id_generator(8)+'-'+id_generator(4)+'-'+id_generator(4)+'-'+id_generator(4)+'-'+id_generator(12))
        me.Data.TimestampUtc=hour

        


        #typeOrder=['OrderPlaced','OrderAccepted','OrderCancelled']
        me_1 = Object()
        me_1.Type = typeOrder[2]
        me_1.Data = Object()
        me_1.Data.OrderId = (id_generator(8)+'-'+id_generator(4)+'-'+id_generator(4)+'-'+id_generator(4)+'-'+id_generator(12))
        me_1.Data.TimestampUtc=hour
    
    

    print(me.toJSON())
    print(me_1.toJSON())
    
    
import argparse

parser = argparse.ArgumentParser(description='Process some integers.')
parser.add_argument('integers', metavar='N', type=int, nargs='+',
                    help='an integer for the accumulator')
parser.add_argument('--sum', dest='accumulate', action='store_const',
                    const=sum, default=max,
                    help='sum the integers (default: find the max)')

args = parser.parse_args()
print(args(1
          ))
# Out:
# {
#     "Type": "OrderPlaced",
#     "Data": {
#         "OrderId": "x1py15u7-3ao4-pkis-6zlh-oakklict1wzk",
#         "TimestampUtc": "2018-01-07T18:25:13Z"
#     }
# }
# {
#     "Type": "OrderAccepted",
#     "Data": {
#         "OrderId": "qeh9lgl3-sjgg-ws74-w66w-30gs7m1xcqfm",
#         "TimestampUtc": "2018-01-07T18:25:13Z"
#     }
# }
# {
#     "Type": "OrderPlaced",
#     "Data": {
#         "OrderId": "yc95un4d-nr2q-dsqp-9xnh-t3z4tict4ppt",
#         "TimestampUtc": "2018-01-07T18:25:13Z"
#     }
# }
# {
#     "Type": "OrderAccepted",
#     "Data": {
#         "OrderId": "w6bqrqoe-bfz0-gl2x-7xw9-koq2jcfjnijc",
#         "TimestampUtc": "2018-01-07T18:25:13Z"
#     }
# }
# {
#     "Type": "OrderPlaced",
#     "Data": {
#         "OrderId": "7j8bhad8-0258-zy7q-97q0-j2tl708l2zju",
#         "TimestampUtc": "2018-01-07T18:25:13Z"
#     }
# }
# {
#     "Type": "OrderAccepted",
#     "Data": {
#         "OrderId": "tm4yzwqb-7oa1-aejf-sy37-fb1ztqftgapz",
#         "TimestampUtc": "2018-01-07T18:25:13Z"
#     }
# }
# {
#     "Type": "OrderPlaced",
#     "Data": {
#         "OrderId": "2me55phc-euw7-iifh-hmsk-hy6x8y58v5pf",
#         "TimestampUtc": "2018-01-07T18:25:13Z"
#     }
# }
# {
#     "Type": "OrderCancelled",
#     "Data": {
#         "OrderId": "a82pa290-1rr8-s88m-84a3-6kahm4r9lv16",
#         "TimestampUtc": "2018-01-07T18:25:13Z"
#     }
# }
# {
#     "Type": "OrderPlaced",
#     "Data": {
#         "OrderId": "5cpb4hp1-b8in-jzav-8kq0-hcdgzmhjce20",
#         "TimestampUtc": "2018-01-07T18:25:13Z"
#     }
# }
# {
#     "Type": "OrderCancelled",
#     "Data": {
#         "OrderId": "rhn690yd-vbuy-4eba-86c7-1b4zb9w72xd4",
#         "TimestampUtc": "2018-01-07T18:25:13Z"
#     }
# }
